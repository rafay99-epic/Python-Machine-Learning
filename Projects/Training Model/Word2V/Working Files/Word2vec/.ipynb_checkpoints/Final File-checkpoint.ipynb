# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.stem.porter import *
import re
from wordsegment import load, segment, clean
load() #loading segment
import matplotlib.pyplot as plt
# %matplotlib inline

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import warnings
warnings.filterwarnings('ignore')
#nltk.download()
import csv
from csv import reader
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings
  
warnings.filterwarnings(action = 'ignore')
  
import gensim
from gensim.models import Word2Vec

# %% [markdown]
# ### Reading CSV File of Pre-Processing of data

# %%
df2 = pd.read_csv('Pre-Processing-Data.csv', header='infer')

# %%
# Display the data frame
df2
# Out:
#                                                   tweets  ClassLabel
# 0      user when a father is dysfunctional and is so ...           0
# 1      user user thanks for ly ft credit i cant use c...           0
# 2                                   bih day your majesty           0
# 3          model i love u take with u all the time in ur           0
# 4                     facts guide society now motivation           0
# ...                                                  ...         ...
# 31957                          ate user is z that you uu           0
# 31958  to seen in a turner on the airwaves trying to ...           0
# 31959  listening to sad songs on a monday morning otw...           0
# 31960  user sikh temple vandalised in in calgary wso ...           1
# 31961                      thank you user for you follow           0
#
# [31962 rows x 2 columns]

# %% [markdown]
# ### Word Tokenization

# %%
word_tokenizer = nltk.WordPunctTokenizer()
word_tokens = [word_tokenizer.tokenize(sent) for sent in df2.tweets]
word_tokens
# Out:
# [['user',
#   'when',
#   'a',
#   'father',
#   'is',
#   'dysfunctional',
#   'and',
#   'is',
#   'so',
#   'selfish',
#   'he',
#   'drags',
#   'his',
#   'kids',
#   'into',
#   'his',
#   'dysfunction',
#   'run'],
#  ['user',
#   'user',
#   'thanks',
#   'for',
#   'ly',
#   'ft',
#   'credit',
#   'i',
#   'cant',
#   'use',
#   'cause',
#   'they',
#   'dont',
#   'offer',
#   'wheelchair',
#   'vans',
#   'in',
#   'pdx',
#   'disapointed',
#   'get',
#   'thanked'],
#  ['bih', 'day', 'your', 'majesty'],
#  ['model',
#   'i',
#   'love',
#   'u',
#   'take',
#   'with',
#   'u',
#   'all',
#   'the',
#   'time',
#   'in',
#   'ur'],
#  ['facts', 'guide', 'society', 'now', 'motivation'],
#  ['22huge',
#   'fanfare',
#   'and',
#   'big',
#   'talking',
#   'before',
#   'they',
#   'leave',
#   'chaos',
#   'and',
#   'pay',
#   'disputes',
#   'when',
#   'they',
#   'get',
#   'there',
#   'all',
#   'show',
#   'and',
#   'no',
#   'go'],
#  ['user',
#   'camping',
# ...

# %%
len(word_tokens)
# Out:
# 31962

# %% [markdown]
# ### Applying the Word2Vec Model

# %%
model = Word2Vec(word_tokens, min_count = 1, window = 5, sg = 1)

# %% [markdown]
# ### Finding the values for word hate

# %%
v1 = model.wv['hate']
print(v1)
# Out:
# [-0.16812164  0.0782601   0.5185194   0.01035413 -0.29911986 -0.41894418
#   0.05232558  0.39972323 -0.26390553 -0.01758317 -0.41745073 -0.6434358
#  -0.05085649  0.14355475  0.14163977  0.42030442  0.20412658 -0.09006494
#   0.0442853  -0.66147864 -0.14166875  0.554482    0.25462    -0.26867032
#  -0.11351261  0.06090276 -0.46075305 -0.49889943 -0.18061435  0.20057335
#   0.64197123  0.29582044  0.10879617 -0.18718128 -0.38266358  0.3841035
#  -0.44947526  0.14723991  0.29901373 -0.06049144  0.36052752 -0.6371975
#   0.08542109 -0.1571968   0.28807157 -0.04320733 -0.2852723   0.12893002
#   0.01920296  0.1499235   0.18592484 -0.42032647 -0.25814947 -0.05028863
#  -0.73797375  0.29480746  0.21964574  0.03415388 -0.05864127  0.11754009
#   0.21177904  0.20791331  0.06319676  0.3534933   0.46272048  0.6354312
#  -0.3221342   0.11483681 -0.44413903  0.20880847  0.26759353  0.153756
#   0.08398552 -0.00491784  0.82506883 -0.1045026  -0.1573214  -0.2608978
# ...

# %% [markdown]
# ### Finding the Similar Word

# %%
sim_words = model.wv.most_similar('fuck')
print(sim_words)
# Out:
# [('shit', 0.9457104802131653), ('wtf', 0.9233657717704773), ('fucking', 0.9166028499603271), ('tell', 0.913217306137085), ('nigga', 0.9128784537315369), ('names', 0.9124205112457275), ('anymore', 0.9114071726799011), ('confused', 0.9113808274269104), ('cuz', 0.9095773696899414), ('nobody', 0.9092110395431519)]

# %% [markdown]
# ### Saving Model

# %%
model.save("word2vec.model")

# %%
model.save("word2vec.csv")
